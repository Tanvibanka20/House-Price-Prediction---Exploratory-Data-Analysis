# %% [markdown]
# # EDA

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# - It is the process to know more about the data
# - It is exploring the data
# - It is the process to have a look upon the data from different angles and perspectives
# - It is the process to understand the different aspects of the data

# %% [markdown]
# ## Steps

# %% [markdown]
# - Shape
# - Basic information (datatypes)
# - column names
# - statistical summary
# - Check for the null values
# - Check for the duplicate values
# - Check for the outliers
# - Treat the null values
# - Treat the duplicate values
# - Treat the outliers
# - Check for coorelation
# - Analysis

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
dt = pd.read_csv("Bengaluru_House_Data.csv")

# %%
dt.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# ## Shape

# %%
dt.shape
# Out:
# (13320, 9)

# %%
# We have 13320 rows and 9 columns

# %% [markdown]
# ## Columns

# %%
dt.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %% [markdown]
# ## Basic Information

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
# 6 Object columns and 3 numeric columns

# %% [markdown]
# ## Statistical Summary

# %%
dt.describe().style.background_gradient(cmap='Reds',low = 0.5, high = 1.0, axis = 1)
# Out:
# <style type="text/css">
# #T_724d8_row0_col0 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_724d8_row0_col1, #T_724d8_row1_col1, #T_724d8_row2_col0, #T_724d8_row2_col1, #T_724d8_row3_col1, #T_724d8_row4_col1, #T_724d8_row5_col0, #T_724d8_row5_col1, #T_724d8_row6_col1, #T_724d8_row7_col1 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_724d8_row0_col2, #T_724d8_row1_col2, #T_724d8_row2_col2, #T_724d8_row3_col2, #T_724d8_row4_col2, #T_724d8_row5_col2, #T_724d8_row6_col2, #T_724d8_row7_col2 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_724d8_row1_col0, #T_724d8_row6_col0, #T_724d8_row7_col0 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_724d8_row3_col0 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_724d8_row4_col0 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# </style>
# <table id="T_724d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_724d8_level0_col0" class="col_heading level0 col0" >bath</th>
#       <th id="T_724d8_level0_col1" class="col_heading level0 col1" >balcony</th>
#       <th id="T_724d8_level0_col2" class="col_heading level0 col2" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_724d8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_724d8_row0_col0" class="data row0 col0" >13247.000000</td>
#       <td id="T_724d8_row0_col1" class="data row0 col1" >12711.000000</td>
#       <td id="T_724d8_row0_col2" class="data row0 col2" >13320.000000</td>
#     </tr>
#     <tr>
#       <th id="T_724d8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_724d8_row1_col0" class="data row1 col0" >2.692610</td>
#       <td id="T_724d8_row1_col1" class="data row1 col1" >1.584376</td>
#       <td id="T_724d8_row1_col2" class="data row1 col2" >112.565627</td>
#     </tr>
#     <tr>
#       <th id="T_724d8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_724d8_row2_col0" class="data row2 col0" >1.341458</td>
#       <td id="T_724d8_row2_col1" class="data row2 col1" >0.817263</td>
#       <td id="T_724d8_row2_col2" class="data row2 col2" >148.971674</td>
#     </tr>
#     <tr>
#       <th id="T_724d8_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_724d8_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_724d8_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_724d8_row3_col2" class="data row3 col2" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_724d8_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_724d8_row4_col0" class="data row4 col0" >2.000000</td>
#       <td id="T_724d8_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_724d8_row4_col2" class="data row4 col2" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_724d8_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_724d8_row5_col0" class="data row5 col0" >2.000000</td>
#       <td id="T_724d8_row5_col1" class="data row5 col1" >2.000000</td>
#       <td id="T_724d8_row5_col2" class="data row5 col2" >72.000000</td>
#     </tr>
#     <tr>
#       <th id="T_724d8_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_724d8_row6_col0" class="data row6 col0" >3.000000</td>
#       <td id="T_724d8_row6_col1" class="data row6 col1" >2.000000</td>
#       <td id="T_724d8_row6_col2" class="data row6 col2" >120.000000</td>
#     </tr>
#     <tr>
#       <th id="T_724d8_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_724d8_row7_col0" class="data row7 col0" >40.000000</td>
#       <td id="T_724d8_row7_col1" class="data row7 col1" >3.000000</td>
#       <td id="T_724d8_row7_col2" class="data row7 col2" >3600.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Check for null values

# %%
dt.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
# location, size, society, bath, balcony columns have the null values

# %% [markdown]
# ## Check for the duplicate values

# %%
dt.duplicated().sum()
# Out:
# 529

# %%
dt[dt.duplicated()]
# Out:
#                   area_type   availability          location       size  \
# 971    Super built-up  Area  Ready To Move      Haralur Road      3 BHK
# 1115   Super built-up  Area  Ready To Move      Haralur Road      2 BHK
# 1143   Super built-up  Area  Ready To Move       Vittasandra      2 BHK
# 1290   Super built-up  Area  Ready To Move      Haralur Road      2 BHK
# 1394   Super built-up  Area  Ready To Move      Haralur Road      2 BHK
# ...                     ...            ...               ...        ...
# 13285  Super built-up  Area  Ready To Move      VHBCS Layout      2 BHK
# 13299  Super built-up  Area         18-Dec        Whitefield      4 BHK
# 13311            Plot  Area  Ready To Move  Ramamurthy Nagar  7 Bedroom
# 13313  Super built-up  Area  Ready To Move       Uttarahalli      3 BHK
# 13319  Super built-up  Area  Ready To Move      Doddathoguru      1 BHK
#
#        society   total_sqft  bath  balcony  price
# 971    NRowse          1464   3.0      2.0   56.0
# 1115       NaN         1027   2.0      2.0   44.0
# 1143   Prlla C         1246   2.0      1.0   64.5
# 1290       NaN         1194   2.0      2.0   47.0
# 1394       NaN         1027   2.0      2.0   44.0
# ...        ...          ...   ...      ...    ...
# 13285  OlarkLa         1353   2.0      2.0  110.0
# 13299  Prtates  2830 - 2882   5.0      0.0  154.5
# 13311      NaN         1500   9.0      2.0  250.0
# 13313  Aklia R         1345   2.0      1.0   57.0
# 13319      NaN          550   1.0      1.0   17.0
#
# [529 rows x 9 columns]

# %%
# We have 529 rows as duplicate rows.

# %% [markdown]
# ## Dropping the Duplicates

# %%
dt.drop_duplicates(inplace= True)

# %%
dt.duplicated().sum()
# Out:
# 0

# %%
# No duplicates are available, we have successfully removed the duplicates

# %% [markdown]
# ## Treating the Null Values

# %% [markdown]
# - We can drop the null values
# - We can impute the null values (filling the null values with some other values)
# - Before filling the null values we have to check whether a column is discrete or categorical

# %%
dt.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5328
# total_sqft         0
# bath              73
# balcony          605
# price              0
# dtype: int64

# %%
dt.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
# Object column will be treated as categorical.
# Numerical column may be discrete or categorical.

# %%
# If the column is categorical then we generally fill the null values with the mode value.
# If the column is discrete then we generally fill the null values with median or mean.

# %%
dt.location.dtype
# Out:
# dtype('O')

# %%
dt.location.fillna(dt.location.mode()[0],inplace = True)

# %%
dt.location.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Size

# %%
dt['size'].dtype  # datatype was int, to find out we need object data type, by writing like this, we can have object datatype
# Out:
# dtype('O')

# %%
dt['size'].mode()[0]
# Out:
# '2 BHK'

# %%
dt['size'].fillna(dt['size'].mode()[0],inplace=True)

# %%
dt['size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Society

# %%
dt.isna().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size               0
# society         5328
# total_sqft         0
# bath              73
# balcony          605
# price              0
# dtype: int64

# %% [markdown]
# - if any column has more than 30% null values, we drop that column

# %%
dt.society.dtype
# Out:
# dtype('O')

# %%
dt.society.isna().sum()*100/len(dt)
# Out:
# 41.654288171370496

# %% [markdown]
# - Since 40% values are null values, we can drop the society columns

# %%
dt.drop('society', axis = 1, inplace = True)

# %%
dt.head() # To check dropped society column
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#   total_sqft  bath  balcony   price
# 0       1056   2.0      1.0   39.07
# 1       2600   5.0      3.0  120.00
# 2       1440   2.0      3.0   62.00
# 3       1521   3.0      1.0   95.00
# 4       1200   2.0      1.0   51.00

# %% [markdown]
# ## Bath

# %%
dt.bath.dtype
# Out:
# dtype('float64')

# %%
dt.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
# we should treat bath as categorical data as it has limited values like 2,3, 5 etc.

# %%
dt.bath.fillna(dt.bath.mode()[0], inplace = True)

# %%
dt.isna().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# total_sqft        0
# bath              0
# balcony         605
# price             0
# dtype: int64

# %% [markdown]
# ## Balcony

# %%
dt.balcony.dtype
# Out:
# dtype('float64')

# %%
dt.balcony.nunique()
# Out:
# 4

# %%
dt.balcony.fillna(dt.balcony.mode()[0], inplace = True)

# %%
dt.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %% [markdown]
# - We have successfully treated the null values

# %%
dt.drop_duplicates(inplace = True)

# %%
dt.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Outliers

# %% [markdown]
# - Outliers detection
# - Outliers removal
# - Analysis
# - Data Transformation

# %% [markdown]
# ### Outliers' Detection

# %% [markdown]
# Meaning of Outlier :
# - A few data points those are significantly different from rest of the data points.
# - If any data point is far from the mean value can be treated as an outlier.

# %%
# To detect outliers we use boxplot

# %% [markdown]
# ## price

# %%
sns.boxplot(y= 'price', data = dt)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## total_sqft

# %%
dt.total_sqft.describe()
# Out:
# count     12751
# unique     2117
# top        1200
# freq        803
# Name: total_sqft, dtype: object

# %%
dt.total_sqft.dtype
# Out:
# dtype('O')

# %%
dt.total_sqft.unique()
#datatype is object and for changing the same into int we need to split the data as hyphens ('-') are present here
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
dt[dt.total_sqft.str.contains('-')]['total_sqft'].str.split('-')
# Out:
# 30       [2100 ,  2850]
# 56       [3010 ,  3410]
# 81       [2957 ,  3450]
# 122      [3067 ,  8156]
# 137      [1042 ,  1105]
#               ...
# 12975     [850 ,  1060]
# 12990    [1804 ,  2273]
# 13059    [1200 ,  1470]
# 13240    [1020 ,  1130]
# 13265    [1133 ,  1384]
# Name: total_sqft, Length: 200, dtype: object

# %%
ind = dt[dt.total_sqft.str.contains('-')].index

# %%
ind
# Out:
# Index([   30,    56,    81,   122,   137,   165,   188,   224,   549,   579,
#        ...
#        12435, 12544, 12791, 12861, 12955, 12975, 12990, 13059, 13240, 13265],
#       dtype='int64', length=200)

# %%
s = dt[dt.total_sqft.str.contains('-')]['total_sqft'].str.split('-')

# %%
lst = []
for i in s:
    lst.append((float(i[0])+float(i[1]))/2)

# %%
print(lst)
# Out:
# [2475.0, 3210.0, 3203.5, 5611.5, 1073.5, 1242.5, 1277.5, 1630.0, 1317.5, 1800.0, 1132.5, 5520.0, 4046.0, 5600.0, 1177.5, 4624.5, 1122.5, 582.5, 1142.5, 4348.5, 657.5, 649.5, 1450.0, 1000.0, 971.5, 1662.0, 687.325, 615.0, 3430.0, 2038.5, 3715.0, 665.0, 4624.5, 776.5, 2817.5, 3817.0, 3461.0, 1277.5, 825.0, 1128.76, 3715.0, 1104.0, 790.5, 3035.0, 3181.0, 3539.5, 2856.0, 700.0, 1559.0, 1352.5, 1800.0, 1950.0, 1185.5, 1005.0, 1707.0, 1476.0, 3181.0, 1192.5, 2912.5, 630.5, 1530.0, 717.0, 1664.0, 3185.0, 4303.5, 1343.5, 3416.5, 1312.5, 1137.5, 458.0, 2345.0, 709.0, 605.0, 2094.0, 2987.5, 2072.5, 1089.0, 1625.0, 2661.0, 680.0, 412.5, 3752.5, 805.5, 709.0, 1462.5, 1891.0, 1617.5, 1302.5, 975.0, 2585.5, 630.5, 2648.0, 614.5, 4334.0, 2336.5, 1302.5, 3317.5, 1405.0, 1532.5, 3550.0, 2856.0, 2856.0, 1583.0, 1115.0, 1162.5, 1580.0, 1272.5, 925.0, 2856.0, 698.5, 1730.0, 1431.5, 4062.5, 1029.5, 2195.0, 1495.0, 778.0, 1155.0, 3496.5, 1700.0, 1522.5, 784.0, 3385.5, 777.0, 2464.5, 640.0, 1773.5, 3854.5, 3181.0, 4920.0, 1745.0, 762.5, 693.0, 800.0, 728.5, 2302.5, 800.0, 1800.0, 552.5, 1495.0, 775.0, 1732.5, 1532.5, 1560.0, 1131.0, 2835.0, 1260.0, 1081.5, 2065.5, 583.0, 790.5, 1237.5, 711.0, 2895.5, 801.0, 2630.0, 863.0, 5020.0, 1315.0, 1530.0, 612.5, 907.0, 2820.0, 458.0, 1360.0, 3715.0, 720.0, 1773.5, 1172.0, 747.0, 1500.0, 1590.0, 1570.0, 1322.5, 3517.0, 1003.5, 2187.5, 1639.5, 2585.5, 827.5, 1355.0, 1195.0, 2500.0, 1187.0, 5667.5, 777.0, 825.0, 1830.5, 2858.0, 705.0, 1410.5, 4225.0, 1122.5, 2283.0, 1533.0, 955.0, 2038.5, 1335.0, 1075.0, 1258.5]

# %%
ind
# Out:
# Index([   30,    56,    81,   122,   137,   165,   188,   224,   549,   579,
#        ...
#        12435, 12544, 12791, 12861, 12955, 12975, 12990, 13059, 13240, 13265],
#       dtype='int64', length=200)

# %%
dt.loc[ind, 'total_sqft'] = lst
dt.loc[ind]
# Out:
#                   area_type   availability            location       size  \
# 30     Super built-up  Area         19-Dec           Yelahanka      4 BHK
# 56           Built-up  Area         20-Feb         Devanahalli  4 Bedroom
# 81           Built-up  Area         18-Oct         Hennur Road  4 Bedroom
# 122    Super built-up  Area         18-Mar              Hebbal      4 BHK
# 137    Super built-up  Area         19-Mar  8th Phase JP Nagar      2 BHK
# ...                     ...            ...                 ...        ...
# 12975  Super built-up  Area         20-Aug          Whitefield      2 BHK
# 12990  Super built-up  Area         18-May      Talaghattapura      3 BHK
# 13059  Super built-up  Area  Ready To Move              Harlur      2 BHK
# 13240  Super built-up  Area  Ready To Move         Devanahalli      1 BHK
# 13265  Super built-up  Area         20-Sep               Hoodi      2 BHK
#
#       total_sqft  bath  balcony    price
# 30        2475.0   4.0      0.0  186.000
# 56        3210.0   2.0      2.0  192.000
# 81        3203.5   2.0      2.0  224.500
# 122       5611.5   4.0      0.0  477.000
# 137       1073.5   2.0      0.0   54.005
# ...          ...   ...      ...      ...
# 12975      955.0   2.0      0.0   38.190
# 12990     2038.5   3.0      0.0  122.000
# 13059     1335.0   2.0      0.0   72.760
# 13240     1075.0   2.0      2.0   52.570
# 13265     1258.5   2.0      0.0   59.135
#
# [200 rows x 8 columns]

# %%
dt.total_sqft.str.contains('-').sum()
# Out:
# 0

# %%
dt.isna().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
dt.total_sqft.replace('[A-Za-z. ]', '',regex = True, inplace = True)

# %%
dt.total_sqft = dt.total_sqft.astype(float)

# %%
sns.boxplot(y='total_sqft', data = dt)
plt.show()

# %% [markdown]
# ### Outliers Removal

# %% [markdown]
# ### IQR Method

# %%
# We cap the values between upper bound and lower bound

# %%
#upper bound = q3+1.5*iqr
#lower bound = q3-1.5*iqr
# iqr = q3 - q1
# q3 = 75th percentile value
# q1 = 25th percentile value

# %%
def outlier(data):
    
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3-q1
    upper_bound = q3+1.5*iqr
    lower_bound = q1-1.5*iqr
    
    return data.clip(upper_bound, lower_bound)

# %%
dt.total_sqft.describe()
# Out:
# count     12751.000000
# mean       2436.581412
# std       13206.996703
# min           1.000000
# 25%        1100.000000
# 50%        1285.000000
# 75%        1700.000000
# max      566584.000000
# Name: total_sqft, dtype: float64

# %%
# np.where() can be used to cap the values
# np.clip() can be used to cap the values

# %%
dt['Total']= outlier(dt.total_sqft)

# %%
dt.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    total_sqft  bath  balcony   price   Total
# 0      1056.0   2.0      1.0   39.07  1056.0
# 1      2600.0   5.0      3.0  120.00  2600.0
# 2      1440.0   2.0      3.0   62.00  1440.0
# 3      1521.0   3.0      1.0   95.00  1521.0
# 4      1200.0   2.0      1.0   51.00  1200.0

# %%
dt[['total_sqft', 'Total']].describe()
# Out:
#           total_sqft         Total
# count   12751.000000  12751.000000
# mean     2436.581412   1445.561218
# std     13206.996703    551.105820
# min         1.000000    200.000000
# 25%      1100.000000   1100.000000
# 50%      1285.000000   1285.000000
# 75%      1700.000000   1700.000000
# max    566584.000000   2600.000000

# %%
sns.boxplot(y = 'Total', data = dt)
# Out:
# <Axes: ylabel='Total'>

# %%
dt['New_Price']= outlier(dt.price)

# %%
dt.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    total_sqft  bath  balcony   price   Total  New_Price
# 0      1056.0   2.0      1.0   39.07  1056.0      39.07
# 1      2600.0   5.0      3.0  120.00  2600.0     120.00
# 2      1440.0   2.0      3.0   62.00  1440.0      62.00
# 3      1521.0   3.0      1.0   95.00  1521.0      95.00
# 4      1200.0   2.0      1.0   51.00  1200.0      51.00

# %%
dt[['price','New_Price']].describe()
# Out:
#               price     New_Price
# count  12751.000000  12751.000000
# mean     114.492961     94.929162
# std      151.676492     61.225221
# min        8.000000      8.000000
# 25%       50.000000     50.000000
# 50%       73.000000     73.000000
# 75%      122.000000    122.000000
# max     3600.000000    230.000000

# %%
sns.boxplot(y = 'New_Price', data = dt)
# Out:
# <Axes: ylabel='New_Price'>

# %% [markdown]
#  ## Analysis

# %% [markdown]
# ### Average price according to area type

# %%
dt.area_type.unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
plt.figure(figsize=(10,6), dpi=100)
ax = sns.barplot(x='area_type', y='price', data = dt, ci= False) #CI for removing mark of confidence intervals
for i in ax.containers:  #bar_labels to get valuemark on bars
    plt.bar_label(i, fmt = '%.2f') # rounding upto 2 decimals

plt.show()

# %% [markdown]
# ### relationship between price and total sq ft

# %%
plt.figure(figsize = (10,8), dpi = 100)
sns.scatterplot(x = 'Total', y = "New_Price", hue = "area_type", data = dt)
plt.xlabel('Total Squarefeet Area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### Observations according to the area type is

# %%
plt.figure(figsize = (10,8), dpi = 100)
ax = sns.countplot(x= 'area_type', data = dt)
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# ### Ratio of the areatype

# %%
plt.figure(figsize=(10,6),dpi = 100)
plt.pie(dt.area_type.value_counts(), labels = dt.area_type.value_counts().index, autopct='%.2f%%')
plt.legend()
plt.show()

# %%
dt.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    total_sqft  bath  balcony   price   Total  New_Price
# 0      1056.0   2.0      1.0   39.07  1056.0      39.07
# 1      2600.0   5.0      3.0  120.00  2600.0     120.00
# 2      1440.0   2.0      3.0   62.00  1440.0      62.00
# 3      1521.0   3.0      1.0   95.00  1521.0      95.00
# 4      1200.0   2.0      1.0   51.00  1200.0      51.00

# %%
x = dt[(dt['size']=='2 BHK') | (dt['size']=='3 BHK') | (dt['size']=='4 BHK')]
x
# Out:
#                   area_type   availability                  location   size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2 BHK
# 2            Built-up  Area  Ready To Move               Uttarahalli  3 BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3 BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2 BHK
# 5      Super built-up  Area  Ready To Move                Whitefield  2 BHK
# ...                     ...            ...                       ...    ...
# 13312  Super built-up  Area  Ready To Move                 Bellandur  2 BHK
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  3 BHK
# 13316  Super built-up  Area  Ready To Move             Richards Town  4 BHK
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2 BHK
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  4 BHK
#
#        total_sqft  bath  balcony   price   Total  New_Price
# 0          1056.0   2.0      1.0   39.07  1056.0      39.07
# 2          1440.0   2.0      3.0   62.00  1440.0      62.00
# 3          1521.0   3.0      1.0   95.00  1521.0      95.00
# 4          1200.0   2.0      1.0   51.00  1200.0      51.00
# 5          1170.0   2.0      1.0   38.00  1170.0      38.00
# ...           ...   ...      ...     ...     ...        ...
# 13312      1262.0   2.0      2.0   47.00  1262.0      47.00
# 13314      1715.0   3.0      3.0  112.00  1715.0     112.00
# 13316      3600.0   5.0      2.0  400.00  2600.0     230.00
# 13317      1141.0   2.0      1.0   60.00  1141.0      60.00
# 13318      4689.0   4.0      1.0  488.00  2600.0     230.00
#
# [9601 rows x 10 columns]

# %% [markdown]
# ### Average price of 2BHK, 3BHK and 4BHK apartments

# %%
plt.figure(figsize = (10,6), dpi = 100)
ax = sns.barplot(x = 'size', y= 'price', data = x, ci= False)
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %% [markdown]
# ### Maximum price of 2BHK, 3BHK and 4BHK apartments

# %%
plt.figure(figsize = (10,6), dpi = 100)
ax = sns.barplot(x = 'size', y= 'price', data = x, ci= False, estimator = np.max)
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %% [markdown]
# ### Minimum price of 2BHK, 3BHK and 4BHK apartments

# %%
plt.figure(figsize = (10,6), dpi = 100)
ax = sns.barplot(x = 'size', y= 'price', data = x, ci= False, estimator = np.min)
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12751 entries, 0 to 13318
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12751 non-null  object
#  1   availability  12751 non-null  object
#  2   location      12751 non-null  object
#  3   size          12751 non-null  object
#  4   total_sqft    12751 non-null  float64
#  5   bath          12751 non-null  float64
#  6   balcony       12751 non-null  float64
#  7   price         12751 non-null  float64
#  8   Total         12751 non-null  float64
#  9   New_Price     12751 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.6+ MB

# %%
df = dt.select_dtypes(include=['float64']).columns

# %%
float_data = dt[df]
# here split t

# %%
plt.figure(figsize = (10,8))
sns.heatmap(float_data.corr(), annot = True, cmap = "YlGnBu", fmt = ".2f") # for decimal point
plt.title("Heatmaps")
plt.show()
